# %%
import pandas
mydata={
    'Dairyproduct':["Milk","Yougurt","Basundi","Paneer"],
    'Quantity':[4,5,2,9],
    'Price':[80,120,200,450]
}
my=pandas.DataFrame(mydata)
print(my)
# Out:
#   Dairyproduct  Quantity  Price
# 0         Milk         4     80
# 1      Yougurt         5    120
# 2      Basundi         2    200
# 3       Paneer         9    450

# %%
import pandas as pd
a=[77,68,80]
a1=pd.Series(a,["Div A","Div B","Div C"])
print(a1)
# Out:
# Div A    77
# Div B    68
# Div C    80
# dtype: int64

# %%
import pandas as pd
s1=["x","y","z"]
s2=pd.Series(s1,[20,38,49])
print(s2)
# Out:
# 20    x
# 38    y
# 49    z
# dtype: object

# %%
import pandas as pd
s1={"january":31,"february":28,"March":31,"April":30}
s2=pd.Series(s1,index=["january","April"])
print(s2)
# Out:
# january    31
# April      30
# dtype: int64

# %%
import matplotlib.pyplot as plt
x=[2,3,5,6]
y=[4,9,25,36]
plt.plot(x,y)
plt.title("line plot example")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,3,5,6]
y=[4,9,25,36]
plt.bar(x,y)
plt.title("line plot example")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,50,2,40])
plt.plot(ypoints,'o:r')
plt.show()
